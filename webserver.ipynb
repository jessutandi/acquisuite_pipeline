# %%
from flask import Flask, flash, request, redirect, url_for

app = Flask(__name__)
app.secret_key = "super secret"

@app.route('/', methods = ['GET', 'POST'])
def default():
    print("--Entering default()--")
    print("HEADERS: ", request.headers)
    print("REQ_PATH: ", request.path)
    print("ARGS: ", request.args)
    print("DATA: ", request.data)
    print("FORM: ", request.form)
    
    return
    
if __name__ == "__main__":
    app.run(host="0.0.0.0", port=80)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:80/ (Press CTRL+C to quit)
# [2019-06-20 14:32:06,095] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 26, in _run_wsgi_app
#     return _run_wsgi_app(*args)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1816, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1831, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1982, in make_response
#     reraise(TypeError, new_error, sys.exc_info()[2])
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\_compat.py", line 34, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 26, in _run_wsgi_app
#     return _run_wsgi_app(*args)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
# The view function did not return a valid response. The return type must be a string, tuple, Response instance, or WSGI callable, but it was a bool.
# 127.0.0.1 - - [20/Jun/2019 14:32:06] "GET / HTTP/1.1" 500 -
# --Entering default()--
# HEADERS:  Host: localhost
# Connection: keep-alive
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3
# Accept-Encoding: gzip, deflate, br
# Accept-Language: en-US,en;q=0.9
# Cookie: username-localhost-8888="2|1:0|10:1561065753|23:username-localhost-8888|44:ZDA3ZmVkMDBhMDI4NGQxMmFiNGQyYTFhNjIxY2U2M2Q=|cb74ed49e1ba36fca35b6758a35c0c3db9a26869a6992ed732b0be6e1d6405c1"; _xsrf=2|5b35eda4|6a6a69c44f333e352565bdb3d7d6885a|1561065753
#
#
# REQ_PATH:  /
# ARGS:  ImmutableMultiDict([])
# DATA:  b''
# FORM:  ImmutableMultiDict([])
# 127.0.0.1 - - [20/Jun/2019 14:35:37] "GET /wpad.dat HTTP/1.1" 404 -
# 127.0.0.1 - - [20/Jun/2019 14:35:45] "GET /wpad.dat HTTP/1.1" 404 -
# 127.0.0.1 - - [20/Jun/2019 14:36:12] "GET /wpad.dat HTTP/1.1" 404 -
# 127.0.0.1 - - [20/Jun/2019 14:36:20] "GET /wpad.dat HTTP/1.1" 404 -
# [2019-06-20 14:37:17,835] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1816, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1831, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1982, in make_response
#     reraise(TypeError, new_error, sys.exc_info()[2])
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\_compat.py", line 34, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
# The view function did not return a valid response. The return type must be a string, tuple, Response instance, or WSGI callable, but it was a bool.
# 127.0.0.1 - - [20/Jun/2019 14:37:17] "GET / HTTP/1.1" 500 -
# --Entering default()--
# HEADERS:  Host: localhost
# Connection: keep-alive
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3
# Accept-Encoding: gzip, deflate, br
# Accept-Language: en-US,en;q=0.9
# Cookie: username-localhost-8888="2|1:0|10:1561065753|23:username-localhost-8888|44:ZDA3ZmVkMDBhMDI4NGQxMmFiNGQyYTFhNjIxY2U2M2Q=|cb74ed49e1ba36fca35b6758a35c0c3db9a26869a6992ed732b0be6e1d6405c1"; _xsrf=2|5b35eda4|6a6a69c44f333e352565bdb3d7d6885a|1561065753
#
#
# REQ_PATH:  /
# ARGS:  ImmutableMultiDict([])
# DATA:  b''
# FORM:  ImmutableMultiDict([])
# [2019-06-20 14:38:16,403] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1816, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1831, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1982, in make_response
#     reraise(TypeError, new_error, sys.exc_info()[2])
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\_compat.py", line 34, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
# The view function did not return a valid response. The return type must be a string, tuple, Response instance, or WSGI callable, but it was a bool.
# 127.0.0.1 - - [20/Jun/2019 14:38:16] "GET / HTTP/1.1" 500 -
# --Entering default()--
# HEADERS:  Host: localhost
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3
# Accept-Encoding: gzip, deflate, br
# Accept-Language: en-US,en;q=0.9
# Cookie: username-localhost-8888="2|1:0|10:1561065753|23:username-localhost-8888|44:ZDA3ZmVkMDBhMDI4NGQxMmFiNGQyYTFhNjIxY2U2M2Q=|cb74ed49e1ba36fca35b6758a35c0c3db9a26869a6992ed732b0be6e1d6405c1"; _xsrf=2|5b35eda4|6a6a69c44f333e352565bdb3d7d6885a|1561065753
#
#
# REQ_PATH:  /
# ARGS:  ImmutableMultiDict([])
# DATA:  b''
# FORM:  ImmutableMultiDict([])
# [2019-06-20 14:38:34,235] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1816, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1831, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1982, in make_response
#     reraise(TypeError, new_error, sys.exc_info()[2])
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\_compat.py", line 34, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
# The view function did not return a valid response. The return type must be a string, tuple, Response instance, or WSGI callable, but it was a bool.
# 127.0.0.1 - - [20/Jun/2019 14:38:34] "GET / HTTP/1.1" 500 -
# --Entering default()--
# HEADERS:  Host: localhost
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3
# Accept-Encoding: gzip, deflate, br
# Accept-Language: en-US,en;q=0.9
# Cookie: username-localhost-8888="2|1:0|10:1561065753|23:username-localhost-8888|44:ZDA3ZmVkMDBhMDI4NGQxMmFiNGQyYTFhNjIxY2U2M2Q=|cb74ed49e1ba36fca35b6758a35c0c3db9a26869a6992ed732b0be6e1d6405c1"; _xsrf=2|5b35eda4|6a6a69c44f333e352565bdb3d7d6885a|1561065753
#
#
# REQ_PATH:  /
# ARGS:  ImmutableMultiDict([])
# DATA:  b''
# FORM:  ImmutableMultiDict([])
# 131.243.229.12 - - [20/Jun/2019 14:39:35] "GET /wpad.dat HTTP/1.1" 404 -
# [2019-06-20 14:40:22,756] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 2292, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1816, in full_dispatch_request
#     return self.finalize_request(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1831, in finalize_request
#     response = self.make_response(rv)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1982, in make_response
#     reraise(TypeError, new_error, sys.exc_info()[2])
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\_compat.py", line 34, in reraise
#     raise value.with_traceback(tb)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\flask\app.py", line 1974, in make_response
#     rv = self.response_class.force_type(rv, request.environ)
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\wrappers\base_response.py", line 269, in force_type
#     response = BaseResponse(*_run_wsgi_app(response, environ))
#   File "C:\Users\thoma\AppData\Roaming\Python\Python37\site-packages\werkzeug\test.py", line 1119, in run_wsgi_app
#     app_rv = app(environ, start_response)
# TypeError: 'bool' object is not callable
# The view function did not return a valid response. The return type must be a string, tuple, Response instance, or WSGI callable, but it was a bool.
# 127.0.0.1 - - [20/Jun/2019 14:40:22] "GET / HTTP/1.1" 500 -
# --Entering default()--
# HEADERS:  Host: localhost
# Connection: keep-alive
# Cache-Control: max-age=0
# Upgrade-Insecure-Requests: 1
# User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36
# Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3
# Accept-Encoding: gzip, deflate, br
# Accept-Language: en-US,en;q=0.9
# Cookie: username-localhost-8888="2|1:0|10:1561065753|23:username-localhost-8888|44:ZDA3ZmVkMDBhMDI4NGQxMmFiNGQyYTFhNjIxY2U2M2Q=|cb74ed49e1ba36fca35b6758a35c0c3db9a26869a6992ed732b0be6e1d6405c1"; _xsrf=2|5b35eda4|6a6a69c44f333e352565bdb3d7d6885a|1561065753
#
#
# REQ_PATH:  /
# ARGS:  ImmutableMultiDict([])
# DATA:  b''
# FORM:  ImmutableMultiDict([])
